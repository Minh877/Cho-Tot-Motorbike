# %%
#pip install selenium
#pip install pyyaml ua-parser user-agents fake-useragent

# %% [markdown]
# 0. Web scraping

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
import pandas as pd

# Setting up the chrome driver: pretend to be an organic user
options = Options()
ua = UserAgent()
a = ua.random
user_agent = ua.random
options.add_argument(f'user-agent={user_agent}')
    
# The url for scraping
soup = []
for index in range(1,101): #Scraping multiple pages of a website
    url = 'https://xe.chotot.com/mua-ban-xe-may?page={0}'.format(index)
    driver = webdriver.Chrome(options=options, executable_path=r'D:\Software\chromedriver_win32 chrome_97\chromedriver.exe')
    driver.get(url)
    data = driver.page_source
    soup_index = BeautifulSoup(data, 'html.parser') # --> Data is stored in soup
    soup.append(soup_index)
# Out:
# C:\Users\MINH\AppData\Local\Temp/ipykernel_38468/60369201.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options, executable_path=r'D:\Software\chromedriver_win32 chrome_97\chromedriver.exe')

# %%
soup[0]
# Out:
# Hình thức mua hàng</span><span class="ItemStyles_filterItemValuePlaceholder__SvsIB">+</span></div></div><i aria-label="Prev" class="WrapperScroll_iconPrev__8xNYl false" role="button" style="left: -40px;" tabindex="0"></i><i aria-label="Next" class="WrapperScroll_iconNext__3co-M WrapperScroll_iconNextActive__2FEyZ" role="button" style="right: -40px;" tabindex="0"></i></div></div><div class="wvwmkj-0 ekTTbO ctTooltip ctTooltiptop ctTooltipShow entitlementProtectionTooltip" color="#222222" id="entitlementProtectionTooltip" style="left: -46.4px; top: 142px;"><div class="ctTooltipOverlay" role="presentation"></div><div class="ctTooltipArrow ctTooltipArrowtop"></div><div class="ctTooltipContent" role="presentation">Lọc với “Đối tác Chợ Tốt” để tìm xe chất lượng hơn</div></div><div class="styles_base__2D2wo"><header><div class="Style_googleDfpDesktopTop__3M5Am Style_paddB__AWFAG} text-center"><div><div data-google-query-id="CPP90bLM3vUCFT-FrAIdnVUIbg" id="rgpt-2"><div id="google_ads_iframe_/325540922/oneweb_des_top1_list_728x90_970x90_0__container__" style="border: 0pt none;"><iframe data-google-container-id="1" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/325540922/oneweb_des_top1_list_728x90_970x90_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/325540922/oneweb_des_top1_list_728x90_970x90_0" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="728"></iframe></div></div></div></div><div><div class="BreadCrumb_wrapperOverflow__3hzbK"><ol class="BreadCrumb_breadcrumb__27OdC" itemscope="" itemtype="http://schema.org/BreadcrumbList"><li class="BreadCrumb_breadcrumbItem__1gyD_ BreadCrumb_link__34LjR" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta content="1" itemprop="position"/><a href="https://xe.chotot.com" itemprop="item"><span itemprop="name">Chợ Tốt Xe</span></a></li><li class="BreadCrumb_breadcrumbItem__1gyD_" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><span itemprop="name" style="color:#222222">Xe máy</span><meta content="2" itemprop="position"/></li></ol><i aria-label="Prev" class="BreadCrumb_iconPrev__Av107 false" role="button" tabindex="0"></i><i aria-label="Next" class="BreadCrumb_iconNext__3m9NB false" role="button" tabindex="0"></i></div></div><div class="MetaTitle_wrapper__1LWSl"><h1 class="MetaTitle_title__1OFZv MetaTitle_heading1__2nLh2" itemprop="name">Giá xe máy cập nhật tháng 02/2022</h1></div></header><main><div class="no-padding col-md-8 ct-col-8"><div class="WrapperScroll_wrapperOverflow__1AXEo"><div class="styles_quickFilterContent__q441F"><div id="0" role="menuitem"><a href="/mua-ban-xe-may-honda-sdmb1" style="color: inherit;"><div class="styles_itemCircle__37YrE" role="button" tabindex="0"><div class="styles_itemCircleIconFlat__250M1"><img class="styles_itemCircleIcon__3inZI" src="https://cdn.chotot.com/admincentre/honda11.png"/></div><p class="styles_itemCircleLabel__2t24e">Honda</p></div></a></div><div id="1" role="menuitem"><a href="/mua-ban-xe-may-yamaha-sdmb2" style="color: inherit;"><div class="styles_itemCircle__37YrE" role="button" tabindex="0"><div class="styles_itemCircleIconFlat__250M1"><img class="styles_itemCircleIcon__3inZI" src="https://cdn.chotot.com/admincentre/yamaha.png"/></div><p class="styles_itemCircleLabel__2t24e">Yamaha</p></div></a></div><div id="2" role="menuitem"><a href="/mua-ban-xe-may-suzuki-sdmb4" style="color: inherit;"><div class="styles_itemCircle__37YrE" role="button" tabindex="0"><div class="styles_itemCircleIconFlat__250M1"><img class="styles_itemCircleIcon__3inZI" src="https://cdn.chotot.com/admincentre/suzuki.png"/></div><p class="styles_itemCircleLabel__2t24e">Suzuki</p></div></a></div><div id="3" role="menuitem"><a href="/mua-ban-xe-may-piaggio-sdmb3" style="color: inherit;"><div class="styles_itemCircle__37YrE" role="button" tabindex="0"><div class="styles_itemCircleIconFlat__250M1"><img class="styles_i ...
# <script>if (typeof(admsspPosition) == "undefined") {_admloadJs("//media1.admicro.vn/core/ssppage.js", function () {admsspPosition({sspid:10313,w:300,h:600, group: ""}); });} else {admsspPosition({sspid:10313,w:300,h:600, group: "", isNoBrand:false});}</script></div></div></div></div> </div></div></div></div></main><footer><div class="hidden internal-link"><ul><li><a href="https://xe.chotot.com/mua-ban-xe-may-bac-ninh"><span>Mua bán Xe máy     tại Bắc Ninh</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-phu-tho"><span>Mua bán Xe máy     tại Phú Thọ</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-ha-nam"><span>Mua bán Xe máy     tại Hà Nam</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-hai-duong"><span>Mua bán Xe máy     tại Hải Dương</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-hoa-binh"><span>Mua bán Xe máy     tại Hòa Bình</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-hung-yen"><span>Mua bán Xe máy     tại Hưng Yên</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-ninh-binh"><span>Mua bán Xe máy     tại Ninh Bình</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-vinh-phuc"><span>Mua bán Xe máy     tại Vĩnh Phúc</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-ba-ria-vung-tau"><span>Mua bán Xe máy     tại Bà Rịa - Vũng Tàu</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-binh-duong"><span>Mua bán Xe máy     tại Bình Dương</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-binh-phuoc"><span>Mua bán Xe máy     tại Bình Phước</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-dong-nai"><span>Mua bán Xe máy     tại Đồng Nai</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-tay-ninh"><span>Mua bán Xe máy     tại Tây Ninh</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-quang-nam"><span>Mua bán Xe máy     tại Quảng Nam</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-da-nang"><span>Mua bán Xe máy     tại Đà Nẵng</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-hai-phong"><span>Mua bán Xe máy     tại Hải Phòng</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-nam-dinh"><span>Mua bán Xe máy     tại Nam Định</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-thai-binh"><span>Mua bán Xe máy     tại Thái Bình</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-an-giang"><span>Mua bán Xe máy     tại An Giang</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-bac-lieu"><span>Mua bán Xe máy     tại Bạc Liêu</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-ben-tre"><span>Mua bán Xe máy     tại Bến Tre</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-can-tho"><span>Mua bán Xe máy     tại Cần Thơ</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-ca-mau"><span>Mua bán Xe máy     tại Cà Mau</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-dong-thap"><span>Mua bán Xe máy     tại Đồng Tháp</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-hau-giang"><span>Mua bán Xe máy     tại Hậu Giang</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-kien-giang"><span>Mua bán Xe máy     tại Kiên Giang</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-long-an"><span>Mua bán Xe máy     tại Long An</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-soc-trang"><span>Mua bán Xe máy     tại Sóc Trăng</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-tien-giang"><span>Mua bán Xe máy     tại Tiền Giang</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-tra-vinh"><span>Mua bán Xe máy     tại Trà Vinh</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-vinh-long"><span>Mua bán Xe máy     tại Vĩnh Long</span></a></li><li><a href="https://xe.chotot.com/mua-ban-xe-may-quang-binh"><span>Mua bán Xe máy     tại Quảng Bình ...
# function getCookie(a){for(var b=document.cookie.split(";"),c,d=0;d<b.length;d++){var e=b[d].trim();0===e.indexOf(a+"\x3d")&&(c=e.substring((a+"\x3d").length,e.length))}return c};</script><script id="" type="text/javascript">function generateUUID(){var a=(new Date).getTime();"undefined"!==typeof performance&&"function"===typeof performance.now&&(a+=performance.now());return"xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx".replace(/[xy]/g,function(c){var b=(a+16*Math.random())%16|0;a=Math.floor(a/16);return("x"===c?b:b&3|8).toString(16)})}if(!getCookie("ctfp")){var uuid=generateUUID();setPersistentCookie("ctfp",uuid,3650)};</script>
# <script id="" type="text/javascript">if(!window.fbq){var pixelId="673880382740519";!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.defer=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://static.chotot.com/storage/production/sdk/fbevents.js");fbq("init",pixelId)}fbq("track","PageView");</script>
# <script id="" type="text/javascript">+function(c,g,h,k,a){c.appboy={};c.appboyQueue=[];a="DeviceProperties Card Card.prototype.dismissCard Card.prototype.removeAllSubscriptions Card.prototype.removeSubscription Card.prototype.subscribeToClickedEvent Card.prototype.subscribeToDismissedEvent Banner CaptionedImage ClassicCard ControlCard ContentCards ContentCards.prototype.getUnviewedCardCount Feed Feed.prototype.getUnreadCardCount ControlMessage InAppMessage InAppMessage.SlideFrom InAppMessage.ClickAction InAppMessage.DismissType InAppMessage.OpenTarget InAppMessage.ImageStyle InAppMessage.Orientation InAppMessage.TextAlignment InAppMessage.CropType InAppMessage.prototype.closeMessage InAppMessage.prototype.removeAllSubscriptions InAppMessage.prototype.removeSubscription InAppMessage.prototype.subscribeToClickedEvent InAppMessage.prototype.subscribeToDismissedEvent FullScreenMessage ModalMessage HtmlMessage SlideUpMessage User User.Genders User.NotificationSubscriptionTypes User.prototype.addAlias User.prototype.addToCustomAttributeArray User.prototype.getUserId User.prototype.incrementCustomUserAttribute User.prototype.removeFromCustomAttributeArray User.prototype.setAvatarImageUrl User.prototype.setCountry User.prototype.setCustomLocationAttribute User.prototype.setCustomUserAttribute User.prototype.setDateOfBirth User.prototype.setEmail User.prototype.setEmailNotificationSubscriptionType User.prototype.setFirstName User.prototype.setGender User.prototype.setHomeCity User.prototype.setLanguage User.prototype.setLastKnownLocation User.prototype.setLastName User.prototype.setPhoneNumber User.prototype.setPushNotificationSubscriptionType InAppMessageButton InAppMessageButton.prototype.removeAllSubscriptions InAppMessageButton.prototype.removeSubscription InAppMessageButton.prototype.subscribeToClickedEvent display display.automaticallyShowNewInAppMessages display.destroyFeed display.hideContentCards display.showContentCards display.showFeed display.showInAppMessage display.toggleContentCards display.toggleFeed changeUser destroy getDeviceId initialize isPushBlocked isPushGranted isPushPermissionGranted isPushSupported logCardClick logCardDismissal logCardImpressions logContentCardsDisplayed logCustomEvent logFeedDisplayed logInAppMessageButtonClick logInAppMessageClick logInAppMessageHtmlClick logInAppMessageImpression logPurchase openSession registerAppboyPushMessages removeAllSubscriptions removeSubscription requestContentCardsRefresh requestFeedRefresh requestImmediateDataFlush resumeWebTracking setLogger setSdkAuthenticationSignature stopWebTracking subscribeToContentCardsUpdates subscribeToFeedUpdates subscribeToInAppMessage subscribeToNewInAppMessages subscribeToSdkAuthenticationFailures toggleAppboyLogging trackLocation unregisterAppboyPushMessages wipeData".split(" ");
# for(var d=0;d<a.length;d++){for(var l=a[d],e=c.appboy,f=l.split("."),b=0;b<f.length-1;b++)e=e[f[b]];e[f[b]]=(new Function("return function "+l.replace(/\./g,"_")+"(){ if(!window.appboyQueue) { window.appboyQueue \x3d [] } window.appboyQueue.push(arguments); return true}"))()}window.appboy.getCachedContentCards=function(){return new window.appboy.ContentCards};window.appboy.getCachedFeed=function(){return new window.appboy.Feed};window.appboy.getUser=function(){return new window.appboy.User};(a=g.createElement(h)).type=
# "text/javascript";a.src="https://js.appboycdn.com/web-sdk/3.3/appboy.min.js";a.defer=1;(k=g.getElementsByTagName(h)[0]).parentNode.insertBefore(a,k)}(window,document,"script");window.appboy.initialize("3f482ca8-a60e-4fbf-8f13-cec3acdede1a",{baseUrl:"sdk.iad-01.braze.com"});window.appboy.display.automaticallyShowNewInAppMessages();window.appboy.registerAppboyPushMessages();window.appboy.openSession();var account_id=getCookie("u.ac");account_id?window.appboy.changeUser(account_id):window.appboy.changeUser(google_tag_manager["GTM-NZKHXF7"].macro(8));</script><script id="" type="text/javascript">setTimeout(function(){(function(a,b,g,e,m,h,k,l,c,f){if(!a[e]||!a[e]._q){for(;l<k.length;)m(h,k[l++]);c=b.createElement(g);c.defer=1;c.src="https://static.chotot.com/storage/production/sdk/branch-latest.min.js";f=b.getElementsByTagName(g)[0];f.parentNode.insertBefore(c,f);a[e]=h}})(window,document,"script","branch",function(a,b){a[b]=function(){a._q.push([b,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "),
# 0);branch.init("key_live_ggRnI3MjIwKeTDlAvtnTvhehtwclvcCG");var d=/www.chotot|nha.chotot|xe.chotot/g.test(location.hostname),n=/^\/(dashboard|bookmark|ssa|chuong-trinh|uu-dai|dangtin|user)/g.test(location.pathname);if(d=d&&!n)d=location.href.replace(/http(s)/g,"chotot-app").replace(/#.*/g,""),branch.setBranchViewData({data:{$deeplink_path:d}})},5E3);</script><div class="ReactModalPortal"></div><script defer="" src="https://static.amcdn.vn/tka/cdn.js"></script><script async="" id="arf-core-js" src="//media1.admicro.vn/cms/Arf.min.js"></script><iframe id="google_osd_static_frame_1676121885309" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe><script id="" type="text/javascript">var serialize=function(a){var b=[],c;for(c in a)a.hasOwnProperty(c)&&b.push(encodeURIComponent(c)+"\x3d"+encodeURIComponent(a[c]));return b.join("\x26")},reFormatAdSource=function(a){var b=Object.assign({},a);a&&a.adsource&&"sticky_ad"===a.adsource&&(b.adsource="stickyad");a="stickyad shop publicProfile similarad zalo facebook messenger viber sms copy NativeAd classifyad cupid personalizead recoad reco_listing special_display_ad".split(" ");0>a.indexOf(b.adsource)&&""!==b.adsource&&(b.adsource="other");
# return b},dataGet=google_tag_manager["GTM-NZKHXF7"].macro(11)||"{}",data=JSON.parse(dataGet),userSession;sessionStorage.getItem("user_session")?userSession=sessionStorage.getItem("user_session"):(userSession=Date.now(),sessionStorage.setItem("user_session",userSession));var page_name;if(-1!==data.adstats_event.indexOf("adsListing/")||-1!==data.adstats_event.indexOf("adlisting/")||data.adstats_event.indexOf("homepage/"))page_name="adlisting";
# if(-1!==data.adstats_event.indexOf("adView/")||-1!==data.adstats_event.indexOf("adview/"))page_name="adview";window.pixelData||(window.pixelData={});window.adviewInfo||(window.adviewInfo={});
# var pixelData={pixelUrl:data.pixelUrl||"",test:"n/a",user_session:userSession||"",user_fingerprint:google_tag_manager["GTM-NZKHXF7"].macro(12)||"",user_oid:"",user_account_id:getCookie("u.ac")||"",user_latitude:"",user_longitude:"",app_os_version:"",app_version:"",page_platform:data.platform||"",page_referer:data.pageReferer||"",page_name:page_name&&"adview"===page_name?"tinview":page_name||"adlisting",page_number:data.page||window.pixelData.page_number||"",browser_useragent:navigator&&navigator.userAgent,browser_viewheight:window.innerHeight||
# "",browser_viewwidth:window.innerWidth||"",event_type:data.payload.view?"load":"click",event_name:data.adstats_event||"",event_client_time:Date.now()||"",filter_keyword:data.filter_keyword||window.pixelData.filter_keyword||"",filter_category_id:data.categoryId||window.pixelData.filter_category_id||"",filter_region_id:data.regionIdAdstats||window.pixelData.filter_region_id||"",filter_type:data.filterType||window.pixelData.filter_type||"",filter_brand:data.filterBrand||window.pixelData.filter_brand||
# "",filter_price:data.filterPrice||window.pixelData.filter_price||"",filter_model:data.filterModel||window.pixelData.filter_model||"",tagging_key:data.taggingKey||window.pixelData.tagging_key||getCookie("AB_test_key")||"",veh_shop_icon:data.VEHShopIcon||window.pixelData.veh_shop_icon||"",elt_shop_icon:data.ELTShopIcon||window.pixelData.elt_shop_icon||"",pty_shop_icon:data.PTYShopIcon||window.pixelData.pty_shop_icon||""},adLisingEvent=["adlisting/CLASSIFYAD_LOAD","adlisting/ADLISTING_RELOAD","adlisting/GET_ADSLISTING_SUCCESS",
# "adlisting/GET_NEXT_ADSLISTING_SUCCESS"],adLisingClickViewEvent=["adlisting/CLICK_ADVIEW","adlisting/ADVIEW_CLICK"],similarAdEvent=["adview/SIMILARAD_LOAD","adlisting/SIMILARAD_LOAD","adview/GET_SIMILAR_ADS_SUCCESS"],cupidAdEvent=["adlisting/CUPID_LOAD"],adViewLeadEvent="adview/SMS_CLICK adview/CALL_CLICK adview/CHAT_CLICK adview/CALL_CLICK_BODY adview/SHOW_PHONE_CLICK adview/SHOW_PHONE_CLICK_BODY".split(" "),allAdViewEvent="adview/SMS_CLICK adview/CALL_CLICK adview/CHAT_CLICK adview/CALL_CLICK_BODY adview/SHOW_PHONE_CLICK adview/SHOW_PHONE_CLICK_BODY adview/ADVIEW_LOAD adview/GET_ADVIEW_SUCCESS adview/TRACKING_PROJECT_ADVIEW".split(" "),
# catMatchingAdViewEvent=["adlisting/RECOAD_CLICK","adlisting/RECOAD_CLICK","adview/RECOAD_LOAD","reco_listing/RECOAD_LOAD"],stickyAdLoadEvent=["adlisting/STICKYAD_LOAD"],stickyAdClickViewEvent=["adlisting/CLICK_ADVIEW"];pixelData.adpremiumads="";pixelData.adplacement=data.payload&&data.payload.placement?data.payload.placement:"";pixelData.adsource=data.payload&&data.payload.source?data.payload.source:"";pixelData.adlist_id=data.listId&&data.listId?data.listId:"";
# pixelData.ad_id=data.adId?data.adId:"";
# if(-1<["adlisting/CLASSIFYAD_LOAD","homepage/PERSONALIZEAD_LOAD"].indexOf(data.adstats_event)&&-1<["shop","publicProfile","personalizead"].indexOf(pixelData.adsource)){var ads=[],adsData=[];data.result&&data.result.ads&&data.result.ads.length&&(ads=data.result.ads.map(function(a){return a.list_id}));var loadData={},placement=pixelData.adplacement||"default",adsList={};adsList[placement]=ads;loadData[pixelData.adsource]=adsList;adsData=[loadData];pixelData.adpremiumads=JSON.stringify(adsData)}else-1<
# adLisingEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.ads&&data.result.ads.length&&(ads=data.result.ads.map(function(a){return a.list_id})),adsData=[{classifyad:{"default":ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):-1<stickyAdLoadEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.listStickyAds&&data.result.listStickyAds.length&&(ads=data.result.listStickyAds.map(function(a){return a.list_id})),adsData=[{stickyad:{top:ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):
# -1<similarAdEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.data&&data.result.data.length&&(ads=data.result.data.map(function(a){return a.list_id})),adsData=[{similarad:{bottom:ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):-1<cupidAdEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.data&&data.result.data.length&&(ads=data.result.data.map(function(a){return a.list_id})),adsData=[{cupid:{"default":ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):-1<
# catMatchingAdViewEvent.indexOf(data.adstats_event)&&(ads=[],data.result&&data.result.data&&data.result.data.length&&(ads=data.result.data.map(function(a){return a.list_id})),adsData=[{recoad:{"default":ads}}],pixelData.adpremiumads=JSON.stringify(adsData));pixelData.adposition=data.adInfo&&data.adInfo.adIndex?parseInt(data.adInfo.adIndex)%21:window.pixelData.adposition||(data.payload&&data.payload.position?data.payload.position:"");
# -1<["adlisting/ADVIEW_CLICK","adview/ADVIEW_LOAD"].indexOf(data.adstats_event)&&(window.adviewInfo={adsource:pixelData.adsource||window.adviewInfo.adsource,adlist_id:pixelData.adlist_id||window.adviewInfo.adlist_id,ad_id:pixelData.ad_id||window.adviewInfo.ad_id,adposition:pixelData.adposition||window.adviewInfo.adposition,page_number:pixelData.page_number||window.adviewInfo.page_number,adplacement:pixelData.adplacement||window.adviewInfo.adplacement});
# -1<allAdViewEvent.indexOf(data.adstats_event)&&(pixelData.adsource=pixelData.adsource||window.adviewInfo.adsource||"other",pixelData.adlist_id=pixelData.adlist_id||window.adviewInfo.adlist_id||"",pixelData.ad_id=pixelData.ad_id||window.adviewInfo.ad_id||"",pixelData.adposition=pixelData.adposition||window.adviewInfo.adposition||"",pixelData.page_number=pixelData.page_number||window.adviewInfo.page_number||"",pixelData.adplacement=pixelData.adplacement||window.adviewInfo.adplacement||"default");
# -1<["adview/SIMILARAD_\bCLICK","adview/SIMILARAD_LOAD"].indexOf(data.adstats_event)&&(pixelData.adposition="",pixelData.page_number="");-1<["adlisting/SIMILARAD_LOAD","adlisting/STICKYAD_LOAD"].indexOf(data.adstats_event)&&(pixelData.adposition="");-1<["adview/ADVIEW_LOAD"].indexOf(data.adstats_event)&&("publicProfile"===pixelData.adsource||"shop"===pixelData.adsource)&&(pixelData.page_number="");
# switch(data.adstats_event){case "adview/SHOW_PHONE_CLICK":pixelData.lead_type="SHOW_PHONE";break;case "adview/SHOW_PHONE_CLICK_BODY":pixelData.lead_type="SHOW_PHONE_BODY";break;case "adview/CALL_CLICK":pixelData.lead_type="CALL";break;case "adview/CALL_CLICK_BODY":pixelData.lead_type="CALL_BODY";break;case "adview/CHAT_CLICK":pixelData.lead_type="CHAT";break;case "adview/SMS_CLICK":pixelData.lead_type="SMS";break;default:pixelData.lead_type=""}pixelData=reFormatAdSource(pixelData);
# window.pixelData=Object.assign(window.pixelData,pixelData);pixelData.from_gtm=!0;pixelData.adstats_tracking_version="11062020";pixelData.tagging_key&&(pixelData.tagging_key=pixelData.tagging_key.toUpperCase());if("adlisting/CLASSIFYAD_LOAD"!==data.adstats_event||data.payload&&data.payload.tracking)document.createElement("img").src=data.pixelUrl+"?"+serialize(pixelData);</script>
# <script id="" type="text/javascript">var serialize=function(a){var b=[],c;for(c in a)a.hasOwnProperty(c)&&b.push(encodeURIComponent(c)+"\x3d"+encodeURIComponent(a[c]));return b.join("\x26")},reFormatAdSource=function(a){var b=Object.assign({},a);a&&a.adsource&&"sticky_ad"===a.adsource&&(b.adsource="stickyad");a="stickyad shop publicProfile similarad zalo facebook messenger viber sms copy NativeAd classifyad cupid personalizead recoad reco_listing special_display_ad".split(" ");0>a.indexOf(b.adsource)&&""!==b.adsource&&(b.adsource="other");
# return b},dataGet=google_tag_manager["GTM-NZKHXF7"].macro(14)||"{}",data=JSON.parse(dataGet),userSession;sessionStorage.getItem("user_session")?userSession=sessionStorage.getItem("user_session"):(userSession=Date.now(),sessionStorage.setItem("user_session",userSession));var page_name;if(-1!==data.adstats_event.indexOf("adsListing/")||-1!==data.adstats_event.indexOf("adlisting/")||data.adstats_event.indexOf("homepage/"))page_name="adlisting";
# if(-1!==data.adstats_event.indexOf("adView/")||-1!==data.adstats_event.indexOf("adview/"))page_name="adview";window.pixelData||(window.pixelData={});window.adviewInfo||(window.adviewInfo={});
# var pixelData={pixelUrl:data.pixelUrl||"",test:"n/a",user_session:userSession||"",user_fingerprint:google_tag_manager["GTM-NZKHXF7"].macro(15)||"",user_oid:"",user_account_id:getCookie("u.ac")||"",user_latitude:"",user_longitude:"",app_os_version:"",app_version:"",page_platform:data.platform||"",page_referer:data.pageReferer||"",page_name:page_name&&"adview"===page_name?"tinview":page_name||"adlisting",page_number:data.page||window.pixelData.page_number||"",browser_useragent:navigator&&navigator.userAgent,browser_viewheight:window.innerHeight||
# "",browser_viewwidth:window.innerWidth||"",event_type:data.payload.view?"load":"click",event_name:data.adstats_event||"",event_client_time:Date.now()||"",filter_keyword:data.filter_keyword||window.pixelData.filter_keyword||"",filter_category_id:data.categoryId||window.pixelData.filter_category_id||"",filter_region_id:data.regionIdAdstats||window.pixelData.filter_region_id||"",filter_type:data.filterType||window.pixelData.filter_type||"",filter_brand:data.filterBrand||window.pixelData.filter_brand||
# "",filter_price:data.filterPrice||window.pixelData.filter_price||"",filter_model:data.filterModel||window.pixelData.filter_model||"",tagging_key:data.taggingKey||window.pixelData.tagging_key||getCookie("AB_test_key")||"",veh_shop_icon:data.VEHShopIcon||window.pixelData.veh_shop_icon||"",elt_shop_icon:data.ELTShopIcon||window.pixelData.elt_shop_icon||"",pty_shop_icon:data.PTYShopIcon||window.pixelData.pty_shop_icon||""},adLisingEvent=["adlisting/CLASSIFYAD_LOAD","adlisting/ADLISTING_RELOAD","adlisting/GET_ADSLISTING_SUCCESS",
# "adlisting/GET_NEXT_ADSLISTING_SUCCESS"],adLisingClickViewEvent=["adlisting/CLICK_ADVIEW","adlisting/ADVIEW_CLICK"],similarAdEvent=["adview/SIMILARAD_LOAD","adlisting/SIMILARAD_LOAD","adview/GET_SIMILAR_ADS_SUCCESS"],cupidAdEvent=["adlisting/CUPID_LOAD"],adViewLeadEvent="adview/SMS_CLICK adview/CALL_CLICK adview/CHAT_CLICK adview/CALL_CLICK_BODY adview/SHOW_PHONE_CLICK adview/SHOW_PHONE_CLICK_BODY".split(" "),allAdViewEvent="adview/SMS_CLICK adview/CALL_CLICK adview/CHAT_CLICK adview/CALL_CLICK_BODY adview/SHOW_PHONE_CLICK adview/SHOW_PHONE_CLICK_BODY adview/ADVIEW_LOAD adview/GET_ADVIEW_SUCCESS adview/TRACKING_PROJECT_ADVIEW".split(" "),
# catMatchingAdViewEvent=["adlisting/RECOAD_CLICK","adlisting/RECOAD_CLICK","adview/RECOAD_LOAD","reco_listing/RECOAD_LOAD"],stickyAdLoadEvent=["adlisting/STICKYAD_LOAD"],stickyAdClickViewEvent=["adlisting/CLICK_ADVIEW"];pixelData.adpremiumads="";pixelData.adplacement=data.payload&&data.payload.placement?data.payload.placement:"";pixelData.adsource=data.payload&&data.payload.source?data.payload.source:"";pixelData.adlist_id=data.listId&&data.listId?data.listId:"";
# pixelData.ad_id=data.adId?data.adId:"";
# if(-1<["adlisting/CLASSIFYAD_LOAD","homepage/PERSONALIZEAD_LOAD"].indexOf(data.adstats_event)&&-1<["shop","publicProfile","personalizead"].indexOf(pixelData.adsource)){var ads=[],adsData=[];data.result&&data.result.ads&&data.result.ads.length&&(ads=data.result.ads.map(function(a){return a.list_id}));var loadData={},placement=pixelData.adplacement||"default",adsList={};adsList[placement]=ads;loadData[pixelData.adsource]=adsList;adsData=[loadData];pixelData.adpremiumads=JSON.stringify(adsData)}else-1<
# adLisingEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.ads&&data.result.ads.length&&(ads=data.result.ads.map(function(a){return a.list_id})),adsData=[{classifyad:{"default":ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):-1<stickyAdLoadEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.listStickyAds&&data.result.listStickyAds.length&&(ads=data.result.listStickyAds.map(function(a){return a.list_id})),adsData=[{stickyad:{top:ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):
# -1<similarAdEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.data&&data.result.data.length&&(ads=data.result.data.map(function(a){return a.list_id})),adsData=[{similarad:{bottom:ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):-1<cupidAdEvent.indexOf(data.adstats_event)?(ads=[],data.result&&data.result.data&&data.result.data.length&&(ads=data.result.data.map(function(a){return a.list_id})),adsData=[{cupid:{"default":ads}}],pixelData.adpremiumads=JSON.stringify(adsData)):-1<
# catMatchingAdViewEvent.indexOf(data.adstats_event)&&(ads=[],data.result&&data.result.data&&data.result.data.length&&(ads=data.result.data.map(function(a){return a.list_id})),adsData=[{recoad:{"default":ads}}],pixelData.adpremiumads=JSON.stringify(adsData));pixelData.adposition=data.adInfo&&data.adInfo.adIndex?parseInt(data.adInfo.adIndex)%21:window.pixelData.adposition||(data.payload&&data.payload.position?data.payload.position:"");
# -1<["adlisting/ADVIEW_CLICK","adview/ADVIEW_LOAD"].indexOf(data.adstats_event)&&(window.adviewInfo={adsource:pixelData.adsource||window.adviewInfo.adsource,adlist_id:pixelData.adlist_id||window.adviewInfo.adlist_id,ad_id:pixelData.ad_id||window.adviewInfo.ad_id,adposition:pixelData.adposition||window.adviewInfo.adposition,page_number:pixelData.page_number||window.adviewInfo.page_number,adplacement:pixelData.adplacement||window.adviewInfo.adplacement});
# -1<allAdViewEvent.indexOf(data.adstats_event)&&(pixelData.adsource=pixelData.adsource||window.adviewInfo.adsource||"other",pixelData.adlist_id=pixelData.adlist_id||window.adviewInfo.adlist_id||"",pixelData.ad_id=pixelData.ad_id||window.adviewInfo.ad_id||"",pixelData.adposition=pixelData.adposition||window.adviewInfo.adposition||"",pixelData.page_number=pixelData.page_number||window.adviewInfo.page_number||"",pixelData.adplacement=pixelData.adplacement||window.adviewInfo.adplacement||"default");
# -1<["adview/SIMILARAD_\bCLICK","adview/SIMILARAD_LOAD"].indexOf(data.adstats_event)&&(pixelData.adposition="",pixelData.page_number="");-1<["adlisting/SIMILARAD_LOAD","adlisting/STICKYAD_LOAD"].indexOf(data.adstats_event)&&(pixelData.adposition="");-1<["adview/ADVIEW_LOAD"].indexOf(data.adstats_event)&&("publicProfile"===pixelData.adsource||"shop"===pixelData.adsource)&&(pixelData.page_number="");
# switch(data.adstats_event){case "adview/SHOW_PHONE_CLICK":pixelData.lead_type="SHOW_PHONE";break;case "adview/SHOW_PHONE_CLICK_BODY":pixelData.lead_type="SHOW_PHONE_BODY";break;case "adview/CALL_CLICK":pixelData.lead_type="CALL";break;case "adview/CALL_CLICK_BODY":pixelData.lead_type="CALL_BODY";break;case "adview/CHAT_CLICK":pixelData.lead_type="CHAT";break;case "adview/SMS_CLICK":pixelData.lead_type="SMS";break;default:pixelData.lead_type=""}pixelData=reFormatAdSource(pixelData);
# window.pixelData=Object.assign(window.pixelData,pixelData);pixelData.from_gtm=!0;pixelData.adstats_tracking_version="11062020";pixelData.tagging_key&&(pixelData.tagging_key=pixelData.tagging_key.toUpperCase());if("adlisting/CLASSIFYAD_LOAD"!==data.adstats_event||data.payload&&data.payload.tracking)document.createElement("img").src=data.pixelUrl+"?"+serialize(pixelData);</script>
# <script id="" type="text/javascript">!function(d,g,e){d.TiktokAnalyticsObject=e;var a=d[e]=d[e]||[];a.methods="page track identify instances debug on off once ready alias group enableCookie disableCookie".split(" ");a.setAndDefer=function(b,c){b[c]=function(){b.push([c].concat(Array.prototype.slice.call(arguments,0)))}};for(d=0;d<a.methods.length;d++)a.setAndDefer(a,a.methods[d]);a.instance=function(b){b=a._i[b]||[];for(var c=0;c<a.methods.length;c++)a.setAndDefer(b,a.methods[c]);return b};a.load=function(b,c){var f="https://static.chotot.com/storage/production/sdk/ttqevents.js";
# a._i=a._i||{};a._i[b]=[];a._i[b]._u=f;a._t=a._t||{};a._t[b]=+new Date;a._o=a._o||{};a._o[b]=c||{};c=document.createElement("script");c.type="text/javascript";c.defer=!0;c.src=f+"?sdkid\x3d"+b+"\x26lib\x3d"+e;b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(c,b)};a.load("C08IODCBPACVH56ATV10");a.page()}(window,document,"ttq");</script><div><div style="height:0px; width:0px; overflow:hidden;"></div></div><div><div id="_admDivFlashdt" style="visibility:hidden; height:1px; width:1px; position:absolute;bottom:0px; overflow:hidden; left:100px;"></div></div><iframe src="https://bid.g.doubleclick.net/xbbe/pixel?d=KAE" style="display: none;"></iframe><iframe id="admIframeTracking" name="admIframeTracking" src="//lg1.logging.admicro.vn/_tracking1.gif?dg=27a16bfa66b9d313392c00f6526da060&amp;fl=-1.-1.&amp;je=0&amp;sr=1536x864&amp;sc=24&amp;hn=xe.chotot.com&amp;p=%2Fmua-ban-xe-may%3Fpage%3D1&amp;r=&amp;cat=&amp;g=0&amp;i=s%3B1643721672445%3B0%3B0%3B1%3B0%3B0%3B1036x683%3B0%3B0%3B27a16bfa66b9d313392c00f6526da060%3B27a16bfa66b9d313392c00f6526da060%3BGA1.2.2030764423.1643721671%3B-1643721665998%3B0%3B257%3B751%3B62%3B2%3B3132%3B3481&amp;rdm=0.8680380786780351&amp;ce=1&amp;lc=&amp;cr=&amp;ui=" style="width: 12px; height: 12px; visibility: hidden; position: absolute; left: 0px; bottom: 0px; border: none;"></iframe></body><iframe id="__JSBridgeIframe_1.0__" style="display: none;"></iframe><iframe id="__JSBridgeIframe_SetResult_1.0__" style="display: none;"></iframe><iframe id="__JSBridgeIframe__" style="display: none;"></iframe><iframe id="__JSBridgeIframe_SetResult__" style="display: none;"></iframe></html>

# %% [markdown]
# 1. Body of the dataframe

# %%
# name
product_name_list = []
# information
product_infor_list = []
# price
product_price_list = []

# %% [markdown]
# 2. Get the data for the dataframe

# %%
# 1. Get the product name
print('Product name: ' + soup[0].select('a[class*="AdItem_adItem__2O28x"]')[0].select('h3[class*="commonStyle_adTitle__1VYG8"]')[0].text.strip())

# 2. Get the product information
print('Product informaion: ' + soup[0].select('a[class*="AdItem_adItem__2O28x"]')[0].select('span[class*="AdBody_adItemCondition__2aNPA"]')[0].text)

# 3. Get the product price
print('Product price: ' + soup[0].select('a[class*="AdItem_adItem__2O28x"]')[0].select('p[class*="AdBody_adPriceNormal__2_jeN"]')[0].text)
# Out:
# Product name: Wave s110 giấy tờ hợp lệ
# Product informaion: 2012 - Xe số - Đã sử dụng
# Product price: 5.600.000 đ

# %%
for soup_i in soup:
    for product_dtl in soup_i.select('a[class*="AdItem_adItem__2O28x"]'):

        #1. Get the name
        product_name_list.append(product_dtl.select('h3[class*="commonStyle_adTitle__1VYG8"]')[0].text.strip())

        #2. Get the information
        if len(product_dtl.select('span[class*="AdBody_adItemCondition__2aNPA"]')) == 0:
            product_infor_list.append(None)
        else:
            product_infor_list.append(product_dtl.select('span[class*="AdBody_adItemCondition__2aNPA"]')[0].text)

        #3. Get the price
        if len(product_dtl.select('p[class*="AdBody_adPriceNormal__2_jeN"]')) == 0:
            product_price_list.append(None)
        else:
            product_price_list.append(product_dtl.select('p[class*="AdBody_adPriceNormal__2_jeN"]')[0].text)

# %% [markdown]
# 3. Construct the dataframe

# %%
#import pandas as pd
dict_to_df = {'product_name': product_name_list,'product_infor': product_infor_list,'product_price': product_price_list}
df = pd.DataFrame(dict_to_df)
df.head()
# Out:
#                         product_name               product_infor product_price
# 0           Wave s110 giấy tờ hợp lệ   2012 - Xe số - Đã sử dụng   5.600.000 đ
# 1            MUA XE HONDA CŨ,TẬN NHÀ                  Đã sử dụng  58.000.000 đ
# 2          MUA XE CŨ TẬN NHÀ GIÁ CAO  2021 - Tay ga - Đã sử dụng  87.000.000 đ
# 3  MUA MOTOR CŨ ,EM PHỤC PHỤ TẬN NƠI                  Đã sử dụng  31.000.000 đ
# 4     VESPA ĐÈN VUÔNG BS 43 giao lưu  2011 - Tay ga - Đã sử dụng  17.500.000 đ

# %%
df = df.join(
    df['product_infor'].str.split(' - ', expand=True).rename(
        columns={0:'product_year', 1:'product_type', 2:'product_condition'}
        )
    )
df.head()
# Out:
#                         product_name               product_infor  \
# 0           Wave s110 giấy tờ hợp lệ   2012 - Xe số - Đã sử dụng
# 1            MUA XE HONDA CŨ,TẬN NHÀ                  Đã sử dụng
# 2          MUA XE CŨ TẬN NHÀ GIÁ CAO  2021 - Tay ga - Đã sử dụng
# 3  MUA MOTOR CŨ ,EM PHỤC PHỤ TẬN NƠI                  Đã sử dụng
# 4     VESPA ĐÈN VUÔNG BS 43 giao lưu  2011 - Tay ga - Đã sử dụng
#
#   product_price product_year product_type product_condition
# 0   5.600.000 đ         2012        Xe số        Đã sử dụng
# 1  58.000.000 đ   Đã sử dụng         None              None
# 2  87.000.000 đ         2021       Tay ga        Đã sử dụng
# 3  31.000.000 đ   Đã sử dụng         None              None
# 4  17.500.000 đ         2011       Tay ga        Đã sử dụng

# %%
df['sell_buy'] = ''
for i in df.index:
    
    # Change product_price type:
    if df['product_price'][i] == None:
        df['product_price'][i] = 0
    else:
        df['product_price'][i] = df['product_price'][i].replace('.', '').replace(' đ', '')
     
    # Add column 'sell_buy':
    if df['product_condition'][i] == None:
        df['product_condition'][i] = df['product_year'][i]
        df['product_year'][i] = None
        df['sell_buy'][i] = 'Mua'
    else:
        df['sell_buy'][i] = 'Bán'

df['product_price'] = pd.to_numeric(df['product_price'])
df.head()
# Out:
#                         product_name               product_infor  \
# 0           Wave s110 giấy tờ hợp lệ   2012 - Xe số - Đã sử dụng
# 1            MUA XE HONDA CŨ,TẬN NHÀ                  Đã sử dụng
# 2          MUA XE CŨ TẬN NHÀ GIÁ CAO  2021 - Tay ga - Đã sử dụng
# 3  MUA MOTOR CŨ ,EM PHỤC PHỤ TẬN NƠI                  Đã sử dụng
# 4     VESPA ĐÈN VUÔNG BS 43 giao lưu  2011 - Tay ga - Đã sử dụng
#
#    product_price product_year product_type product_condition sell_buy
# 0        5600000         2012        Xe số        Đã sử dụng      Bán
# 1       58000000         None         None        Đã sử dụng      Mua
# 2       87000000         2021       Tay ga        Đã sử dụng      Bán
# 3       31000000         None         None        Đã sử dụng      Mua
# 4       17500000         2011       Tay ga        Đã sử dụng      Bán

# %%
df = df[df['product_price'] < 1000000000]

# %%
df
# Out:
#                                            product_name  \
# 0                              Wave s110 giấy tờ hợp lệ
# 1                               MUA XE HONDA CŨ,TẬN NHÀ
# 2                             MUA XE CŨ TẬN NHÀ GIÁ CAO
# 3                     MUA MOTOR CŨ ,EM PHỤC PHỤ TẬN NƠI
# 4                        VESPA ĐÈN VUÔNG BS 43 giao lưu
# ...                                                 ...
# 2005                sy ý nhập khẩu nguyên con chính chủ
# 2006  ❤Vision đời 2018 Bao Đẹp bstp chính chủ hỗ trợ...
# 2007   Honda Vision 110cc 2012 bstp 196.61 giá rẻ 14tr5
# 2008    Honda Airblade 110cc lên 2 đèn thái bstp 380.18
# 2009                      Yamaha mio bstp xe đẹp mấy êm
#
#                    product_infor  product_price product_year product_type  \
# 0      2012 - Xe số - Đã sử dụng        5600000         2012        Xe số
# 1                     Đã sử dụng       58000000         None         None
# 2     2021 - Tay ga - Đã sử dụng       87000000         2021       Tay ga
# 3                     Đã sử dụng       31000000         None         None
# 4     2011 - Tay ga - Đã sử dụng       17500000         2011       Tay ga
# ...                          ...            ...          ...          ...
# 2005  2005 - Tay ga - Đã sử dụng       52000000         2005       Tay ga
# 2006  2018 - Tay ga - Đã sử dụng       26900000         2018       Tay ga
# 2007  2012 - Tay ga - Đã sử dụng       14500000         2012       Tay ga
# 2008  2008 - Tay ga - Đã sử dụng       13500000         2008       Tay ga
# 2009  2006 - Tay ga - Đã sử dụng        7000000         2006       Tay ga
#
#      product_condition sell_buy
# 0           Đã sử dụng      Bán
# 1           Đã sử dụng      Mua
# 2           Đã sử dụng      Bán
# 3           Đã sử dụng      Mua
# 4           Đã sử dụng      Bán
# ...                ...      ...
# 2005        Đã sử dụng      Bán
# 2006        Đã sử dụng      Bán
# 2007        Đã sử dụng      Bán
# 2008        Đã sử dụng      Bán
# 2009        Đã sử dụng      Bán
#
# [2008 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2008 entries, 0 to 2009
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_name       2008 non-null   object
#  1   product_infor      2008 non-null   object
#  2   product_price      2008 non-null   int64
#  3   product_year       1990 non-null   object
#  4   product_type       1990 non-null   object
#  5   product_condition  2008 non-null   object
#  6   sell_buy           2008 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 125.5+ KB

# %%
df.describe()
# Out:
#        product_price
# count   2.008000e+03
# mean    3.327862e+07
# std     5.379253e+07
# min     0.000000e+00
# 25%     1.027500e+07
# 50%     1.940000e+07
# 75%     3.550000e+07
# max     9.900000e+08

# %% [markdown]
# 4. Push the data to SQL Server

# %%
import pyodbc

# creating a new db and a new table
new_db_name = "ChoTot_Motor"
new_table_name = "ChoTot_Motor"
connection_string = "Driver=SQL Server;Server=DESKTOP-CF5UU1U\SQLEXPRESS;Database={0};Trusted_Connection=Yes;" 
                        # you can also swap Trusted_Connection for UID={your username};PWD={your password}
cnxn = pyodbc.connect(connection_string.format("master"), autocommit=True)
cnxn.cursor().execute('''IF EXISTS(SELECT * FROM sys.databases WHERE [name] = '{0}') DROP DATABASE {0}'''.format(new_db_name))
cnxn.cursor().execute("CREATE DATABASE " + new_db_name)
cnxn.cursor().execute("DROP TABLE IF EXISTS {0}".format(new_table_name))
cnxn.cursor().execute('''USE {1} CREATE TABLE {0}(
                                product_name nvarchar(100), product_infor nvarchar(50)
                                , product_price int, product_year nvarchar(20)
                                , product_type nvarchar(20), product_condition nvarchar(20)
                                , sell_buy nvarchar(5))'''.format(new_table_name, new_db_name))
for index, row in df.iterrows():
    cnxn.cursor().execute('''INSERT INTO dbo.{0}(
                                product_name, product_infor
                                , product_price, product_year
                                , product_type, product_condition
                                , sell_buy) values (?, ?, ?, ?, ?, ?, ?)'''.format(new_table_name)\
                          , row['product_name'], row['product_infor'], row['product_price']\
                          , row['product_year'], row['product_type'], row['product_condition'], row['sell_buy'])
    cnxn.commit()
cnxn.close()

print("Database and table created")
# Out:
# Database and table created

# %% [markdown]
# 5. Export dataframe to .csv, .xlsx

# %%
#df.to_csv(path, index = False, encoding='utf-8')
#df.to_excel(path, index = False)

path = 'D:\#Tự học DA\Project\ChoTot_Motorbike\ChoTot_Motorbike.xlsx'

import os
if os.path.exists(path):
    os.remove(path)

df.to_excel(path, index = False)
